# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Assuming you are working in a Linux or Windows Subsystem for Linux environment, you may need to install some dependencies. Assuming a clean installation, the following will be needed:
#
# ```bash
# sudo apt install jupyter
# sudo apt install python3-pip
# pip install python-frontmatter getorg --upgrade
# ```
#
# After which you can run this from the `_talks/` directory, via:
#
# ```bash
#  jupyter nbconvert --to notebook --execute talkmap.ipynb --output talkmap_out.ipynb
# ```
#
# The `_talks/` directory contains `.md` files of all your talks. This scrapes the location YAML field from each `.md` file, geolocates it with `geopy/Nominatim`, and uses the `getorg` library to output data, HTML, and Javascript for a standalone cluster map.

# %%
# Start by installing the dependencies
# !pip install python-frontmatter getorg --upgrade
import frontmatter
import glob
import getorg
from geopy import Nominatim
from geopy.exc import GeocoderTimedOut
# Out:
# Collecting python-frontmatter
#   Downloading python_frontmatter-1.3.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: getorg in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (0.3.1)
# Requirement already satisfied: pyyaml in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from python-frontmatter) (6.0.3)
# Requirement already satisfied: geopy in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from getorg) (2.5.0)
# Requirement already satisfied: pygithub in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from getorg) (2.10.0)
# Requirement already satisfied: retrying in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from getorg) (1.4.2)
# Requirement already satisfied: geographiclib<3,>=1.52 in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from geopy->getorg) (2.1)
# Requirement already satisfied: pynacl>=1.4.0 in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from pygithub->getorg) (1.6.2)
# Requirement already satisfied: requests>=2.14.0 in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from pygithub->getorg) (2.34.2)
# Requirement already satisfied: pyjwt>=2.4.0 in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (2.13.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from pygithub->getorg) (4.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from pygithub->getorg) (2.7.0)
# Requirement already satisfied: cryptography>=3.4.0 in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (50.0.1)
# Requirement already satisfied: cffi>=2.0.0 in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.4.0->pygithub->getorg) (2.1.1)
# Requirement already satisfied: pycparser in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.4.0->pygithub->getorg) (3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from requests>=2.14.0->pygithub->getorg) (3.5.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from requests>=2.14.0->pygithub->getorg) (3.19)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/hostedtoolcache/Python/3.10.21/x64/lib/python3.10/site-packages (from requests>=2.14.0->pygithub->getorg) (2026.7.22)
# Downloading python_frontmatter-1.3.0-py3-none-any.whl (10 kB)
# Installing collected packages: python-frontmatter
# Successfully installed python-frontmatter-1.3.0
# Iywidgets and ipyleaflet support disabled. You must be in a Jupyter notebook to use this feature.
# Error raised:
# No module named 'ipyleaflet'
# Check that you have enabled ipyleaflet in Jupyter with:
#     jupyter nbextension enable --py ipyleaflet

# %%
# Collect the Markdown files
g = glob.glob("_talks/*.md")

# %%
# Set the default timeout, in seconds
TIMEOUT = 5

# Prepare to geolocate
geocoder = Nominatim(user_agent="academicpages.github.io")
location_dict = {}
location = ""
permalink = ""
title = ""

# %% [markdown]
# In the event that this times out with an error, double check to make sure that the location is can be properly geolocated.

# %%
# Perform geolocation
for file in g:
    # Read the file
    data = frontmatter.load(file)
    data = data.to_dict()

    # Press on if the location is not present
    if 'location' not in data:
        continue

    # Prepare the description
    title = data['title'].strip()
    venue = data['venue'].strip()
    location = data['location'].strip()
    description = f"{title}<br />{venue}; {location}"

    # Geocode the location and report the status
    try:
        location_dict[description] = geocoder.geocode(location, timeout=TIMEOUT)
        print(description, location_dict[description])
    except ValueError as ex:
        print(f"Error: geocode failed on input {location} with message {ex}")
    except GeocoderTimedOut as ex:
        print(f"Error: geocode timed out on input {location} with message {ex}")
    except Exception as ex:
        print(f"An unhandled exception occurred while processing input {location} with message {ex}")
# Out:
# A representation theoretical approach to Lie–Hamilton systems based on the Lie algebra $\mathfrak{sp}(4, \mathbb{R})$ and its applications<br />XXIVth International Conference on Geometry, Integrability and Quantization; Varna, Bulgary None
# Mixed superposition rules for Lie systems: compatible geometric structures and applications<br />XX International Young Researchers Workshop on Geometry, Dynamics and Field Theory; Loughborough, United Kingdom Loughborough, Charnwood, Leicestershire, England, LE11 5BJ, United Kingdom
# Contact Lie systems on three-dimensional Riemannian and Lorentzian spaces of constant curvature<br />RSME's 7th Congress of Young Researchers; Bilbao, Spain Bilbao, Bizkaia, Euskadi, España
# New Lie–Hamilton systems on Riemannian and Lorentzian spaces from conformal transformations and applications<br />XXV Winter Meeting on Geometry, Dynamics and Field Theory; Zaragoza, Spain Zaragoza, Aragón, España
# Lie Theorem for superposition rules for PDEs revisited<br />2nd International Workshop on Geometric Field Theory; Warsaw, Poland Warszawa, województwo mazowieckie, Polska
# Lie’s Theorem for superposition rules revisited<br />XVIII International ICMAT Summer School on Geometry, Dynamics and Field theory; Miraflores de la Sierra, Madrid, Spain Miraflores de la Sierra, Comunidad de Madrid, España
# Curvature-dependent reductions of contact Lie systems on curved spaces<br />XIX Young Researchers Workshop in Geometry Dynamics and Field Theory; Verona, Italy Verona, Veneto, Italia
# Lie systems and supergeometry<br />Geometry and Topology for the future IV; Madrid, Spain Madrid, Comunidad de Madrid, España
# Mixed superposition rules and compatible geometric structures<br />Gamma Seminar; Online Online, Croix d'Argent, Montpellier, Hérault, Occitanie, France métropolitaine, France

# %%
# Save the map
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="talkmap", hashed_usernames=False)
# Out:
# 'Written map to talkmap/'
